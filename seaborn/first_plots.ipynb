# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
videos_df = pd.read_excel('./videosYT.xlsx', 'videos')

# %%
fig = sns.scatterplot(data=videos_df, x='Categoria', y='Nº de Likes', hue='Responsável', palette=['blue', 'green'])
plt.show(fig)

# %%
fig = sns.relplot(data=videos_df, x='Nº de Views', y='Nº de Likes', hue='Responsável', col='Responsável')

# %%
inscritos_df = pd.read_excel('./videosYT.xlsx', 'Inscritos')
fig = sns.lineplot(data=inscritos_df, x='Mês/Ano', y='Inscritos', color='red')

# %%
fig = sns.displot(data=videos_df, x='Nº de Views', kind='ecdf')

# %%
fig = sns.regplot(data=videos_df, x='Nº de Views', y='Nº de Likes')

# %%
fig = sns.lmplot(data=videos_df, x='Nº de Views', y='Nº de Likes', hue='Responsável', markers=['o', '^'])
