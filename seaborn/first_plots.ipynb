# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
videos_df = pd.read_excel('./videosYT.xlsx', 'videos')
videos_df.columns
fig = sns.barplot(data=videos_df, x='Responsável', y='Nº de Likes')
plt.show(fig)
