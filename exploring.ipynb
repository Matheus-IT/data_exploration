# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./consulta_cand_complementar_2024_BRASIL.csv', encoding='latin1', sep=';')

# %%
df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_ELEICAO  SQ_CANDIDATO  \
# 0  17/09/2024   19:31:43         2024         619  250002194009
# 1  17/09/2024   19:31:43         2024         619  250001996723
# 2  17/09/2024   19:31:43         2024         619  250002156370
# 3  17/09/2024   19:31:43         2024         619  250002360470
# 4  17/09/2024   19:31:43         2024         619   50002256288
#
#    CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND  CD_NACIONALIDADE  \
# 0                        -3                      #NE                 1
# 1                        -3                      #NE                 1
# 2                        -3                      #NE                 1
# 3                        -3                      #NE                 1
# 4                        -3                      #NE                 1
#
#   DS_NACIONALIDADE  CD_MUNICIPIO_NASCIMENTO  ...  \
# 0  BRASILEIRA NATA                       -3  ...
# 1  BRASILEIRA NATA                       -3  ...
# ...
